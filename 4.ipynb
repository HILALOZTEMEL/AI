# %%
from sklearn.datasets import load_iris #iris veri seti yükledik
from sklearn import tree #ağaç görüntüsünü elde edebilmek için
iris=load_iris()
X,y=iris.data,iris.target
clf=tree.DecisionTreeClassifier()
clf=clf.fit(X,y)
tree.plot_tree(clf)
[...]
# Out:
# [Ellipsis]
